# %%
import fiddle.graphviz

# %%
import weatherduck.configs.experiment.anemoi as anemoi_cfgs

# %%
cfg = anemoi_cfgs.experiment_factory.as_buildable(dataset_config={}, split_config={}, n_input_data_features=0)
fiddle.graphviz.render(cfg)
